# %% [markdown]
# For $f(x)=sin(\pi~x)$ on $[-1,1]$
# Compute $\mathcal{L}_4$ and $\mathcal{H}_4$
# Build plots, estimate which approximation is better
#
# We wish to Interpolate $f(x)=sin(\pi~x)$ by 4 points using the Lagrange & Hermite methods and then determine which produces a better approximation.

# %%
import numpy as np
import math
from scipy.interpolate import lagrange
from scipy import special

# %%
# x = np.linspace(-1, 1, num=4, endpoint=True) # equally spaced nodes, including endpoint
x = [-1, -1/2, 1/2, 1] # non-equally spaced nodes
deriv = [-1, 0, 0, 1]
y = [math.sin(math.pi * j) for j in x]
poly_l = lagrange(x, y)
poly_h = special.hermite(4, monic=True) # monic=True scales the leading coefficient to 1
print('x=',x,'\ny=',y) # test print
print('poly_h=',poly_h) # test print
# Out:
# x= [-1, -0.5, 0.5, 1]
# y= [-1.2246467991473532e-16, -1.0, 1.0, 1.2246467991473532e-16]
# poly_h=    4     2
# 1 x - 3 x - 5.551e-17 x + 0.75

# %%
from numpy.polynomial.polynomial import Polynomial
# print(Polynomial(poly_l.coef[::-1]).coef) # test print
x_sin = np.linspace(-1, 1, 100, endpoint=True)

# %%
import matplotlib.pyplot as plt
x_new = Polynomial(poly_l.coef[::-1]).coef
y_poly_h = poly_h(x)
y_sin = [math.sin(math.pi * k) for k in x_sin]
plt.plot(x, Polynomial(poly_l.coef[::-1])(x_new), label=r'$\mathcal{L}_{4}$ Polynomial', color='red', linestyle='dashdot')
plt.plot(x, y_poly_h, label=r'$\mathcal{H}_{4}$ Polynomial', color='green', linestyle='dashed')
plt.plot(x_sin, y_sin, label=r'$sin(\pi*x)$', linestyle='dotted', color='blue')
plt.legend(loc='upper center')
plt.title(r'$\mathcal{H}_{4}$, $\mathcal{L}_{4}$, $sin(\pi~x)$')
plt.xlabel(r'$\mathcal{H}_{4}$, $\mathcal{L}_{4}$, $sin(\pi~x) \in [-1, 1]$')
plt.ylabel('Polynomial Approximations')
plt.show()
